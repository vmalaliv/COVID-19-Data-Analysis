# %%
import pandas as pd
import numpy as np

from datetime import datetime

# %matplotlib inline
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ![CRISP_DM](../reports/figures/CRISP_DM.png)

# %% [markdown]
# # Data Preparation

# %% [markdown]
# * focus is always to understand the final data structure
# * support each step by visual analytics

# %% [markdown]
# # Johns Hopkins GITHUB csv data

# %%
data_path='../data/raw/COVID-19-master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
pd_raw=pd.read_csv(data_path)

# %%
pd_raw.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  6/11/22  6/12/22  6/13/22  \
# 0        0        0        0        0  ...   180864   180864   181120
# 1        0        0        0        0  ...   276690   276731   276731
# 2        0        0        0        0  ...   265925   265927   265937
# 3        0        0        0        0  ...    43224    43224    43224
# 4        0        0        0        0  ...    99761    99761    99761
#
#    6/14/22  6/15/22  6/16/22  6/17/22  6/18/22  6/19/22  6/20/22
# 0   181178   181236   181465   181534   181574   181666   181725
# 1   276821   276821   276821   277141   277141   277409   277444
# 2   265943   265952   265964   265968   265971   265975   265985
# 3    43224    43449    43449    43449    43449    43449    43449
# 4    99761    99761    99761    99761    99761    99761    99761
#
# [5 rows x 885 columns]

# %%
time_idx=pd_raw.columns[4:]

# %%
df_plot = pd.DataFrame({
    'date':time_idx})
df_plot.head()
# Out:
#       date
# 0  1/22/20
# 1  1/23/20
# 2  1/24/20
# 3  1/25/20
# 4  1/26/20

# %%
pd_raw['Country/Region']
# Out:
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                               Andorra
# 4                                Angola
# 5                            Antarctica
# 6                   Antigua and Barbuda
# 7                             Argentina
# 8                               Armenia
# 9                             Australia
# 10                            Australia
# 11                            Australia
# 12                            Australia
# 13                            Australia
# 14                            Australia
# 15                            Australia
# 16                            Australia
# 17                              Austria
# 18                           Azerbaijan
# 19                              Bahamas
# 20                              Bahrain
# 21                           Bangladesh
# 22                             Barbados
# 23                              Belarus
# 24                              Belgium
# 25                               Belize
# 26                                Benin
# 27                               Bhutan
# 28                              Bolivia
# 29               Bosnia and Herzegovina
# 30                             Botswana
# 31                               Brazil
# 32                               Brunei
# 33                             Bulgaria
# 34                         Burkina Faso
# 35                                Burma
# 36                              Burundi
# 37                           Cabo Verde
# 38                             Cambodia
# 39                             Cameroon
# 40                               Canada
# 41                               Canada
# 42                               Canada
# 43                               Canada
# 44                               Canada
# 45                               Canada
# 46                               Canada
# 47                               Canada
# 48                               Canada
# 49                               Canada
# 50                               Canada
# 51                               Canada
# 52                               Canada
# 53                               Canada
# 54                               Canada
# 55                               Canada
# 56             Central African Republic
# 57                                 Chad
# 58                                Chile
# 59                                China
# 60                                China
# 61                                China
# 62                                China
# 63                                China
# 64                                China
# 65                                China
# 66                                China
# 67                                China
# 68                                China
# 69                                China
# 70                                China
# 71                                China
# 72                                China
# 73                                China
# 74                                China
# 75                                China
# 76                                China
# 77                                China
# 78                                China
# 79                                China
# 80                                China
# 81                                China
# 82                                China
# 83                                China
# 84                                China
# 85                                China
# 86                                China
# 87                                China
# 88                                China
# 89                                China
# 90                                China
# 91                                China
# 92                                China
# 93                             Colombia
# 94                              Comoros
# 95                  Congo (Brazzaville)
# 96                     Congo (Kinshasa)
# 97                           Costa Rica
# 98                        Cote d'Ivoire
# 99                              Croatia
# 100                                Cuba
# 101                              Cyprus
# 102                             Czechia
# 103                             Denmark
# 104                             Denmark
# 105                             Denmark
# 106                    Diamond Princess
# 107                            Djibouti
# 108                            Dominica
# 109                  Dominican Republic
# 110                             Ecuador
# 111                               Egypt
# 112                         El Salvador
# 113                   Equatorial Guinea
# 114                             Eritrea
# 115                             Estonia
# 116                            Eswatini
# 117                            Ethiopia
# 118                                Fiji
# 119                             Finland
# 120                              France
# 121                              France
# 122                              France
# 123                              France
# 124                              France
# 125                              France
# 126                              France
# 127                              France
# 128                              France
# 129                              France
# 130                              France
# 131                              France
# 132                               Gabon
# 133                              Gambia
# 134                             Georgia
# 135                             Germany
# 136                               Ghana
# 137                              Greece
# 138                             Grenada
# 139                           Guatemala
# 140                              Guinea
# 141                       Guinea-Bissau
# 142                              Guyana
# 143                               Haiti
# 144                            Holy See
# 145                            Honduras
# 146                             Hungary
# 147                             Iceland
# 148                               India
# 149                           Indonesia
# 150                                Iran
# 151                                Iraq
# 152                             Ireland
# 153                              Israel
# 154                               Italy
# 155                             Jamaica
# 156                               Japan
# 157                              Jordan
# 158                          Kazakhstan
# 159                               Kenya
# 160                            Kiribati
# 161                        Korea, North
# 162                        Korea, South
# 163                              Kosovo
# 164                              Kuwait
# 165                          Kyrgyzstan
# 166                                Laos
# 167                              Latvia
# 168                             Lebanon
# 169                             Lesotho
# 170                             Liberia
# 171                               Libya
# 172                       Liechtenstein
# 173                           Lithuania
# 174                          Luxembourg
# 175                          MS Zaandam
# 176                          Madagascar
# 177                              Malawi
# 178                            Malaysia
# 179                            Maldives
# 180                                Mali
# 181                               Malta
# 182                    Marshall Islands
# 183                          Mauritania
# 184                           Mauritius
# 185                              Mexico
# 186                          Micronesia
# 187                             Moldova
# 188                              Monaco
# 189                            Mongolia
# 190                          Montenegro
# 191                             Morocco
# 192                          Mozambique
# 193                             Namibia
# 194                               Nepal
# 195                         Netherlands
# 196                         Netherlands
# 197                         Netherlands
# 198                         Netherlands
# 199                         Netherlands
# 200                         New Zealand
# 201                         New Zealand
# 202                           Nicaragua
# 203                               Niger
# 204                             Nigeria
# 205                     North Macedonia
# 206                              Norway
# 207                                Oman
# 208                            Pakistan
# 209                               Palau
# 210                              Panama
# 211                    Papua New Guinea
# 212                            Paraguay
# 213                                Peru
# 214                         Philippines
# 215                              Poland
# 216                            Portugal
# 217                               Qatar
# 218                             Romania
# 219                              Russia
# 220                              Rwanda
# 221               Saint Kitts and Nevis
# 222                         Saint Lucia
# 223    Saint Vincent and the Grenadines
# 224                               Samoa
# 225                          San Marino
# 226               Sao Tome and Principe
# 227                        Saudi Arabia
# 228                             Senegal
# 229                              Serbia
# 230                          Seychelles
# 231                        Sierra Leone
# 232                           Singapore
# 233                            Slovakia
# 234                            Slovenia
# 235                     Solomon Islands
# 236                             Somalia
# 237                        South Africa
# 238                         South Sudan
# 239                               Spain
# 240                           Sri Lanka
# 241                               Sudan
# 242                Summer Olympics 2020
# 243                            Suriname
# 244                              Sweden
# 245                         Switzerland
# 246                               Syria
# 247                             Taiwan*
# 248                          Tajikistan
# 249                            Tanzania
# 250                            Thailand
# 251                         Timor-Leste
# 252                                Togo
# 253                               Tonga
# 254                 Trinidad and Tobago
# 255                             Tunisia
# 256                              Turkey
# 257                                  US
# 258                              Uganda
# 259                             Ukraine
# 260                United Arab Emirates
# 261                      United Kingdom
# 262                      United Kingdom
# 263                      United Kingdom
# 264                      United Kingdom
# 265                      United Kingdom
# 266                      United Kingdom
# 267                      United Kingdom
# 268                      United Kingdom
# 269                      United Kingdom
# 270                      United Kingdom
# 271                      United Kingdom
# 272                      United Kingdom
# 273                      United Kingdom
# 274                      United Kingdom
# 275                             Uruguay
# 276                          Uzbekistan
# 277                             Vanuatu
# 278                           Venezuela
# 279                             Vietnam
# 280                  West Bank and Gaza
# 281                Winter Olympics 2022
# 282                               Yemen
# 283                              Zambia
# 284                            Zimbabwe
# Name: Country/Region, dtype: object

# %%
pd_raw[pd_raw['Country/Region']=='Germany'].iloc[:,4::].sum(axis=0)[0:4]
# Out:
# 1/22/20    0
# 1/23/20    0
# 1/24/20    0
# 1/25/20    0
# dtype: int64

# %%
country_list=['Italy',
              'US',
              'Spain',
              'Germany',
              'Korea, South',
             ]

# %%
for each in country_list:
    df_plot[each]=np.array(pd_raw[pd_raw['Country/Region']==each].iloc[:,4::].sum(axis=0))

# %%
df_plot.set_index('date').plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# # Data Type Date

# %%
df_plot.head()
# Out:
#       date  Italy  US  Spain  Germany  Korea, South
# 0  1/22/20      0   1      0        0             1
# 1  1/23/20      0   1      0        0             1
# 2  1/24/20      0   2      0        0             2
# 3  1/25/20      0   2      0        0             2
# 4  1/26/20      0   5      0        0             3

# %%
time_idx=[datetime.strptime( each,"%m/%d/%y") for each in df_plot.date] # convert to datetime
time_str=[each.strftime('%Y-%m-%d') for each in time_idx] # convert back to date ISO norm (str)

# %%
df_plot['date']=time_idx
type(df_plot['date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df_plot.head()
# Out:
#         date  Italy  US  Spain  Germany  Korea, South
# 0 2020-01-22      0   1      0        0             1
# 1 2020-01-23      0   1      0        0             1
# 2 2020-01-24      0   2      0        0             2
# 3 2020-01-25      0   2      0        0             2
# 4 2020-01-26      0   5      0        0             3

# %%
df_plot.to_csv('../data/processed/COVID_small_flat_table.csv',sep=';',index=False)

# %% [markdown]
# # Relational data model - defining a primary key
#
# In the relational model of databases, a primary key is a specific choice of a minimal set of attributes (columns) that uniquely specify a tuple (row) in a relation (table) (source: wiki)
#
#
# A primary key’s main features are:
#
# * It must contain a unique value for each row of data.
# * It cannot contain null values.

# %%
data_path='../data/raw/COVID-19-master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
pd_raw=pd.read_csv(data_path)
pd_raw.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  6/11/22  6/12/22  6/13/22  \
# 0        0        0        0        0  ...   180864   180864   181120
# 1        0        0        0        0  ...   276690   276731   276731
# 2        0        0        0        0  ...   265925   265927   265937
# 3        0        0        0        0  ...    43224    43224    43224
# 4        0        0        0        0  ...    99761    99761    99761
#
#    6/14/22  6/15/22  6/16/22  6/17/22  6/18/22  6/19/22  6/20/22
# 0   181178   181236   181465   181534   181574   181666   181725
# 1   276821   276821   276821   277141   277141   277409   277444
# 2   265943   265952   265964   265968   265971   265975   265985
# 3    43224    43449    43449    43449    43449    43449    43449
# 4    99761    99761    99761    99761    99761    99761    99761
#
# [5 rows x 885 columns]

# %%
pd_data_base=pd_raw.rename(columns={'Country/Region':'country',
                      'Province/State':'state'})
pd_data_base['state']=pd_data_base['state'].fillna('no')  #ensure a sring, important for indexing

# %%
pd_data_base=pd_data_base.drop(['Lat','Long'],axis=1)
pd_data_base.head()
# Out:
#   state      country  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0    no  Afghanistan        0        0        0        0        0        0
# 1    no      Albania        0        0        0        0        0        0
# 2    no      Algeria        0        0        0        0        0        0
# 3    no      Andorra        0        0        0        0        0        0
# 4    no       Angola        0        0        0        0        0        0
#
#    1/28/20  1/29/20  ...  6/11/22  6/12/22  6/13/22  6/14/22  6/15/22  \
# 0        0        0  ...   180864   180864   181120   181178   181236
# 1        0        0  ...   276690   276731   276731   276821   276821
# 2        0        0  ...   265925   265927   265937   265943   265952
# 3        0        0  ...    43224    43224    43224    43224    43449
# 4        0        0  ...    99761    99761    99761    99761    99761
#
#    6/16/22  6/17/22  6/18/22  6/19/22  6/20/22
# 0   181465   181534   181574   181666   181725
# 1   276821   277141   277141   277409   277444
# 2   265964   265968   265971   265975   265985
# 3    43449    43449    43449    43449    43449
# 4    99761    99761    99761    99761    99761
#
# [5 rows x 883 columns]

# %%
pd_relational_model=pd_data_base.set_index(['state','country']) \
                                .T                              \
                                .stack(level=[0,1])             \
                                .reset_index()                  \
                                .rename(columns={'level_0':'date',
                                                   0:'confirmed'},
                                                  )
pd_relational_model.head()
# Out:
#       date                         state         country  confirmed
# 0  1/22/20                       Alberta          Canada        0.0
# 1  1/22/20                      Anguilla  United Kingdom        0.0
# 2  1/22/20                         Anhui           China        1.0
# 3  1/22/20                         Aruba     Netherlands        0.0
# 4  1/22/20  Australian Capital Territory       Australia        0.0

# %%
pd_relational_model.dtypes
# Out:
# date          object
# state         object
# country       object
# confirmed    float64
# dtype: object

# %%
pd_relational_model['date']=pd_relational_model.date.astype('datetime64[ns]')

# %%
pd_relational_model.dtypes
# Out:
# date         datetime64[ns]
# state                object
# country              object
# confirmed           float64
# dtype: object

# %%
pd_relational_model.confirmed=pd_relational_model.confirmed.astype(int)

pd_relational_model.to_csv('../data/processed/COVID_relational_confirmed.csv',sep=';',index=False)

# %%
print(pd_relational_model[pd_relational_model['country']=='US'].tail())
# Out:
#              date state country  confirmed
# 249930 2022-06-16    no      US   86058228
# 250215 2022-06-17    no      US   86216418
# 250500 2022-06-18    no      US   86230982
# 250785 2022-06-19    no      US   86246101
# 251070 2022-06-20    no      US   86297081

# %% [markdown]
# # Attention due to the new structure of the Johns Hopkins data set the state information US is in a second file

# %%
data_path='../data/raw/COVID-19-master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv'
pd_raw_US=pd.read_csv(data_path)
pd_raw_US.head()
# Out:
#         UID iso2 iso3  code3    FIPS   Admin2 Province_State Country_Region  \
# 0  84001001   US  USA    840  1001.0  Autauga        Alabama             US
# 1  84001003   US  USA    840  1003.0  Baldwin        Alabama             US
# 2  84001005   US  USA    840  1005.0  Barbour        Alabama             US
# 3  84001007   US  USA    840  1007.0     Bibb        Alabama             US
# 4  84001009   US  USA    840  1009.0   Blount        Alabama             US
#
#          Lat      Long_  ... 6/11/22  6/12/22  6/13/22  6/14/22  6/15/22  \
# 0  32.539527 -86.644082  ...   16095    16095    16134    16158    16174
# 1  30.727750 -87.722071  ...   57166    57166    57366    57453    57554
# 2  31.868263 -85.387129  ...    5748     5748     5757     5764     5769
# 3  32.996421 -87.125115  ...    6547     6547     6565     6573     6583
# 4  33.982109 -86.567906  ...   15137    15137    15150    15174    15177
#
#    6/16/22  6/17/22  6/18/22  6/19/22  6/20/22
# 0    16193    16211    16211    16211    16279
# 1    57637    57726    57726    57726    57887
# 2     5771     5782     5782     5782     5795
# 3     6596     6611     6611     6611     6621
# 4    15188    15207    15207    15207    15222
#
# [5 rows x 892 columns]

# %%
# drop all non relevant fields! 
# Many of this fields do not belong to 
# a transactional data. These fields belong to so called master data
pd_raw_US=pd_raw_US.drop(['UID', 'iso2', 'iso3', 'code3', 'Country_Region','FIPS', 'Admin2',  'Lat', 'Long_', 'Combined_Key'],axis=1)
pd_data_base_US=pd_raw_US.rename(columns={'Province_State':'state'}).copy()

# %%
## the stack command has problems when only one information is available within a stacking level
pd_relational_model_US=pd_data_base_US.set_index(['state']) \
                                .T                              \
                                .stack()             \
                                .reset_index()                  \
                                .rename(columns={'level_0':'date',
                                                   0:'confirmed'},
                                                  )
pd_relational_model_US['country']='US'
pd_relational_model_US['date']=[datetime.strptime( each,"%m/%d/%y") for each in pd_relational_model_US.date] # convert to datetime
pd_relational_model_US.head()
# Out:
#         date    state  confirmed country
# 0 2020-01-22  Alabama          0      US
# 1 2020-01-22  Alabama          0      US
# 2 2020-01-22  Alabama          0      US
# 3 2020-01-22  Alabama          0      US
# 4 2020-01-22  Alabama          0      US

# %% [markdown]
# ### update the large relational file

# %%
pd_relational_model_all=pd_relational_model[pd_relational_model['country']!='US'].reset_index(drop=True)

# %%
pd_relational_model_all=pd.concat([pd_relational_model_all,pd_relational_model_US],ignore_index=True)

# %%
pd_relational_model_all.to_csv('../data/processed/20200424_COVID_relational_confirmed.csv',sep=';',index=False)

# %%
print(pd_relational_model_all[pd_relational_model_all['country']=='US'])
# Out:
#               date    state country  confirmed
# 250204  2020-01-22  Alabama      US          0
# 250205  2020-01-22  Alabama      US          0
# 250206  2020-01-22  Alabama      US          0
# 250207  2020-01-22  Alabama      US          0
# 250208  2020-01-22  Alabama      US          0
# ...            ...      ...     ...        ...
# 3194501 2022-06-20  Wyoming      US      10554
# 3194502 2022-06-20  Wyoming      US       5753
# 3194503 2022-06-20  Wyoming      US          0
# 3194504 2022-06-20  Wyoming      US       2471
# 3194505 2022-06-20  Wyoming      US       1632
#
# [2944302 rows x 4 columns]

# %% [markdown]
# ### cross check on full sum US data

# %%
check_US=pd_relational_model_all[pd_relational_model_all['country']=='US']

# %%
check_US[['date','country','confirmed']].groupby(['date','country']).sum()
# Out:
#                     confirmed
# date       country
# 2020-01-22 US               1
# 2020-01-23 US               1
# 2020-01-24 US               2
# 2020-01-25 US               2
# 2020-01-26 US               5
# ...                       ...
# 2022-06-16 US        86058228
# 2022-06-17 US        86216418
# 2022-06-18 US        86230982
# 2022-06-19 US        86246101
# 2022-06-20 US        86297081
#
# [881 rows x 1 columns]
